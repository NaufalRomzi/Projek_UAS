# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.interpolate as sci

# %%
img = cv2.imread('well 2.png', cv2.IMREAD_UNCHANGED)

# %%
img.shape
# Out:
# (457, 147, 4)

# %%
print('Type of the image : ' , type(img))
print()
print('Shape of the image : {}'.format(img.shape))
print('Image Hight {}'.format(img.shape[0]))
print('Image Width {}'.format(img.shape[1]))
print('Dimension of Image {}'.format(img.ndim))
# Out:
# Type of the image :  <class 'numpy.ndarray'>
#
# Shape of the image : (457, 147, 4)
# Image Hight 457
# Image Width 147
# Dimension of Image 3

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
ret , thresh = cv2.threshold(img_gray, 150, 255, cv2.THRESH_BINARY)

# %%
cv2.imshow('Binary Image', img_gray)
cv2.waitKey(0)
cv2.imwrite('image_thres1.jpg', thresh)
cv2.destroyAllWindows()

# %%
# # detect the contours on the binary image using cv2.CHAIN_APPROX_NONE
# contours, hierarchy = cv2.findContours(image=thresh, mode=cv2.RETR_LIST, method=cv2.CHAIN_APPROX_NONE)
                                     
# # draw contours on the original image
# image_copy = img.copy()
# cv2.drawContours(image=image_copy, contours=contours, contourIdx=-1, color=(0, 255, 0), thickness=2, lineType=cv2.LINE_AA)
               
# # see the results
# cv2.imshow('None approximation', image_copy)
# cv2.waitKey(0)
# # cv2.imwrite('contours_none_image1.jpg', image_copy)
# cv2.destroyAllWindows()

# %% [markdown]
# depth
# txt
# interpolasi

# %%
vector = np.vectorize(np.int8)

ac = np.array((img_gray))
acc = vector(ac)
# y = (printArrays(457))

# %%
ac
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 218, 250, 255],
#        [255, 255, 253, ...,  66, 228, 255],
#        ...,
#        [255, 255, 253, ...,  71, 229, 255],
#        [255, 255, 253, ...,  71, 229, 255],
#        [255, 255, 253, ...,  71, 228, 255]], dtype=uint8)

# %%
# inter = interp1d(y, ac)

# %%
np.savetxt('gray.npy',ac, delimiter='|')

# %%
# plt.figure(figsize=(30,25))
plt.imshow(ac)
# plt.show()

# %%
df = pd.DataFrame(ac, dtype=int)
df.dtypes
# Out:
# 0      int32
# 1      int32
# 2      int32
# 3      int32
# 4      int32
#        ...
# 142    int32
# 143    int32
# 144    int32
# 145    int32
# 146    int32
# Length: 147, dtype: object

# %%
# gridx = np.linspace(0, 1000, num=100, endpoint=False)
# gridy = np.linspace(0, 1000, num=100, endpoint=False)

# xg, yg = np.meshgrid(gridx, gridy)

# # x_g = xg.ravel()
# # y_g = yg.ravel()

pole = sci.NearestNDInterpolator(df, df[50])
pole

# %%
plt.plot(pole, df)
plt.show()

# %% [markdown]
# interpolate the rgbs with depth then plot it
